# %%
#hours studied" and "ExamScore Using this csv file
#we will build a simple linear regression model. Add the following code in main.py file on Github:

import streamlit as st
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 #hours studied" and "ExamScore Using this csv file
#       2 #we will build a simple linear regression model. Add the following code in main.py file on Github:
# ----> 4 import streamlit as st
#       5 import pandas as pd
#       6 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
#Load data fron CSV (Ensure the file has "RoureStudied" and "Exandoura colonnar
df pd.read_cav("Student_Marks.csv")

# %% [markdown]
# plit data into Features (K) and Target tyl
#
# Xdf [['HoursStudied")]
#
# y df[ExamScore")
#
# Train-Zest split (504 training, 20% testing)
#
# X_train, X_test, y train, y test train_test_split (X, y test aize-0.2, random
#
# state-421
#
# Train the model
#
# model LinearRegression ()
#
# model.fit (X train, y train)
#
# Streamlit User Interface
#
# st.title(" Exam Score Predictor")
#
# st.write("Enter hours studied to predict the exan score."
#
# Dner Input
#
# hours st.number input("Hours Studied:", min_value-0.0, stepm
#
# Predict Button
#
# LE st.button("Predict Score":
#
# A
#
# predicted_score model predict([[hours]])[]
#
# st.success(☑ Predicted Score: (predicted_score: 2)")
#
# Show Sample Data
#
# at.write("### Sample Training Data")
#
# st.dataframe (df)
#
# Also update the requirements.txt file as follows:
